# %%
import numpy as np
import pandas as pd
import torch 
import RLVisual as rlv
from agent_dqn import DQN

# %%
# from agent_dqn import DQN

# a = DQN(state_dim=16, action_dim=4)
# a.load_model('results/dqn_model_0.pt')
a = torch.load('results/dqn_model_0.pt')['state_encoder.weight'].cpu().numpy()
q_func = np.load('results/q_func0.npy')

# %%
rlv.plot_3d_bars_transparent(2, q_func)

# %%
rlv.plot_3d_bars_transparent(2, a)

# %%
a.shape
# Out:
# (100, 16)
